# %% [markdown]
# <a href="https://colab.research.google.com/github/hrnnikolov/ML_models/blob/main/Pytorch_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
torch.__version__
# Out:
# '2.2.1+cu121'

# %%
import torchvision
model = torchvision.models.resnet50()

# %%
# pytorch 2
compiled_model = torch.compile(model)

# %%
import torch

# Check PyTorch version
pt_version = torch.__version__
print(f"[INFO] Current PyTorch version: {pt_version} (should be 2.x+)")

# Install PyTorch 2.0 if necessary
if pt_version.split(".")[0] == "1": # Check if PyTorch version begins with 1
    # !pip3 install -U torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
    print("[INFO] PyTorch 2.x installed, if you're on Google Colab, you may need to restart your runtime.\
          Though as of April 2023, Google Colab comes with PyTorch 2.0 pre-installed.")
    import torch
    pt_version = torch.__version__
    print(f"[INFO] Current PyTorch version: {pt_version} (should be 2.x+)")
else:
    print("[INFO] PyTorch 2.x installed, you'll be able to use the new features.")
# Out:
# [INFO] Current PyTorch version: 2.2.1+cu121 (should be 2.x+)
# [INFO] PyTorch 2.x installed, you'll be able to use the new features.

# %%
# Make sure we're using a NVIDIA GPU
if torch.cuda.is_available():
  gpu_info = !nvidia-smi
  gpu_info = '\n'.join(gpu_info)
  if gpu_info.find("failed") >= 0:
    print("Not connected to a GPU, to leverage the best of PyTorch 2.0, you should connect to a GPU.")

  # Get GPU name
  gpu_name = !nvidia-smi --query-gpu=gpu_name --format=csv
  gpu_name = gpu_name[1]
  GPU_NAME = gpu_name.replace(" ", "_") # remove underscores for easier saving
  print(f'GPU name: {GPU_NAME}')

  # Get GPU capability score
  GPU_SCORE = torch.cuda.get_device_capability()
  print(f"GPU capability score: {GPU_SCORE}")
  if GPU_SCORE >= (8, 0):
    print(f"GPU score higher than or equal to (8, 0), PyTorch 2.x speedup features available.")
  else:
    print(f"GPU score lower than (8, 0), PyTorch 2.x speedup features will be limited (PyTorch 2.x speedups happen most on newer GPUs).")

  # Print GPU info
  print(f"GPU information:\n{gpu_info}")

else:
  print("PyTorch couldn't find a GPU, to leverage the best of PyTorch 2.0, you should connect to a GPU.")
# Out:
# GPU name: Tesla_T4
# GPU capability score: (7, 5)
# GPU score lower than (8, 0), PyTorch 2.x speedup features will be limited (PyTorch 2.x speedups happen most on newer GPUs).
# GPU information:
# Mon Apr 22 10:14:10 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   70C    P0              32W /  70W |    813MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# # Globally set devices

# %%
import torch

device = 'cuda' if torch.cuda.is_available() else 'cpu'

#set device with context manager
with torch.device(device):
  # All tensors created in this block will be on device
  layer = torch.nn.Linear(20, 30)
  print(f'Layer weights are on device: {layer.weight.device}')
  print(f'Layer creating data on device: {layer(torch.randn(128, 20)).device}')
# Out:
# Layer weights are on device: cuda:0
# Layer creating data on device: cuda:0

# %%
# set device globally
torch.set_default_device(device)

# %% [markdown]
# # Experiments

# %%
model_weights = torchvision.models.ResNet50_Weights.IMAGENET1K_V1
transforms = model_weights.transforms()

transforms
# Out:
# ImageClassification(
#     crop_size=[224]
#     resize_size=[256]
#     mean=[0.485, 0.456, 0.406]
#     std=[0.229, 0.224, 0.225]
#     interpolation=InterpolationMode.BILINEAR
# )

# %%
model = torchvision.models.resnet50(weights=model_weights)
model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
total_params = sum(
    param.numel() for param in model.parameters()
)

total_params
# Out:
# 25557032

# %%
def create_model(num_classes=10):
  '''Creates a resnet50 model with transforms and returns them both.'''
  model_weights = torchvision.models.ResNet50_Weights.DEFAULT
  transforms = model_weights.transforms()
  model = torchvision.models.resnet50(weights=model_weights)

  #Aadjust the head layer to suit our num of classes
  model.fc = torch.nn.Linear(in_features=2048,
                             out_features=num_classes)
  return model, transforms

# %%
model, transforms = create_model()

# %%
# Check available GPU memory and total GPU memory
total_free_gpu_memory, total_gpu_memory = torch.cuda.mem_get_info()
print(f"Total free GPU memory: {round(total_free_gpu_memory * 1e-9, 3)} GB")
print(f"Total GPU memory: {round(total_gpu_memory * 1e-9, 3)} GB")
# Out:
# Total free GPU memory: 14.759 GB
# Total GPU memory: 15.836 GB

# %%
# Set batch size depending on amount of GPU memory
total_free_gpu_memory_gb = round(total_free_gpu_memory * 1e-9, 3)
if total_free_gpu_memory_gb >= 16:
  BATCH_SIZE = 128 # Note: you could experiment with higher values here if you like.
  IMAGE_SIZE = 224
  print(f"GPU memory available is {total_free_gpu_memory_gb} GB, using batch size of {BATCH_SIZE} and image size {IMAGE_SIZE}")
else:
  BATCH_SIZE = 32
  IMAGE_SIZE = 128
  print(f"GPU memory available is {total_free_gpu_memory_gb} GB, using batch size of {BATCH_SIZE} and image size {IMAGE_SIZE}")
# Out:
# GPU memory available is 14.759 GB, using batch size of 32 and image size 128

# %%
transforms.crop_size = IMAGE_SIZE
transforms.resize_size = IMAGE_SIZE

# %% [markdown]
# # More potential speedups

# %%
if GPU_SCORE >= (8, 0):
  print(f"[INFO] Using GPU with score: {GPU_SCORE}, enabling TensorFloat32 (TF32) computing (faster on new GPUs)")
  torch.backends.cuda.matmul.allow_tf32 = True
else:
  print(f"[INFO] Using GPU with score: {GPU_SCORE}, TensorFloat32 (TF32) not available, to use it you need a GPU with score >= (8, 0)")
  torch.backends.cuda.matmul.allow_tf32 = False
# Out:
# [INFO] Using GPU with score: (7, 5), TensorFloat32 (TF32) not available, to use it you need a GPU with score >= (8, 0)

# %% [markdown]
# # Prepearing dataset

# %%
import torchvision

train_dataset = torchvision.datasets.CIFAR10(root='.',
                                             train=True,
                                             download=True,
                                             transform=transforms)
# Out:
# Files already downloaded and verified

# %%
test_dataset = torchvision.datasets.CIFAR10(root='.',
                                            train=False,
                                            download=True,
                                            transform=transforms)
# Out:
# Files already downloaded and verified

# %%
len(train_dataset), len(test_dataset)
# Out:
# (50000, 10000)

# %%
from torch.utils.data import DataLoader
import os
NUM_WORKERS = 0 #os.cpu_count()

train_dataloader = DataLoader(dataset=train_dataset,
                              batch_size=BATCH_SIZE,
                              shuffle=True,
                              num_workers=NUM_WORKERS,
                              generator=torch.Generator(device='cuda')
                              )

test_dataloader = DataLoader(dataset=test_dataset,
                              batch_size=BATCH_SIZE,
                              shuffle=False,
                              num_workers=NUM_WORKERS
                              )

# %%
NUM_WORKERS
# Out:
# 0

# %% [markdown]
# # Training

# %%
import time
from tqdm.auto import tqdm
from typing import Dict, List, Tuple

def train_step(epoch: int,
               model: torch.nn.Module,
               dataloader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer,
               device: torch.device,
               disable_progress_bar: bool = False) -> Tuple[float, float]:
  """Trains a PyTorch model for a single epoch.

  Turns a target PyTorch model to training mode and then
  runs through all of the required training steps (forward
  pass, loss calculation, optimizer step).

  Args:
    model: A PyTorch model to be trained.
    dataloader: A DataLoader instance for the model to be trained on.
    loss_fn: A PyTorch loss function to minimize.
    optimizer: A PyTorch optimizer to help minimize the loss function.
    device: A target device to compute on (e.g. "cuda" or "cpu").

  Returns:
    A tuple of training loss and training accuracy metrics.
    In the form (train_loss, train_accuracy). For example:

    (0.1112, 0.8743)
  """
  # Put model in train mode
  model.train()

  # Setup train loss and train accuracy values
  train_loss, train_acc = 0, 0

  # Loop through data loader data batches
  progress_bar = tqdm(
        enumerate(dataloader),
        desc=f"Training Epoch {epoch}",
        total=len(dataloader),
        disable=disable_progress_bar
    )

  for batch, (X, y) in progress_bar:
      # Send data to target device
      X, y = X.to(device), y.to(device)

      # 1. Forward pass
      y_pred = model(X)

      # 2. Calculate  and accumulate loss
      loss = loss_fn(y_pred, y)
      train_loss += loss.item()

      # 3. Optimizer zero grad
      optimizer.zero_grad()

      # 4. Loss backward
      loss.backward()

      # 5. Optimizer step
      optimizer.step()

      # Calculate and accumulate accuracy metric across all batches
      y_pred_class = torch.argmax(torch.softmax(y_pred, dim=1), dim=1)
      train_acc += (y_pred_class == y).sum().item()/len(y_pred)

      # Update progress bar
      progress_bar.set_postfix(
            {
                "train_loss": train_loss / (batch + 1),
                "train_acc": train_acc / (batch + 1),
            }
        )


  # Adjust metrics to get average loss and accuracy per batch
  train_loss = train_loss / len(dataloader)
  train_acc = train_acc / len(dataloader)
  return train_loss, train_acc

def test_step(epoch: int,
              model: torch.nn.Module,
              dataloader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module,
              device: torch.device,
              disable_progress_bar: bool = False) -> Tuple[float, float]:
  """Tests a PyTorch model for a single epoch.

  Turns a target PyTorch model to "eval" mode and then performs
  a forward pass on a testing dataset.

  Args:
    model: A PyTorch model to be tested.
    dataloader: A DataLoader instance for the model to be tested on.
    loss_fn: A PyTorch loss function to calculate loss on the test data.
    device: A target device to compute on (e.g. "cuda" or "cpu").

  Returns:
    A tuple of testing loss and testing accuracy metrics.
    In the form (test_loss, test_accuracy). For example:

    (0.0223, 0.8985)
  """
  # Put model in eval mode
  model.eval()

  # Setup test loss and test accuracy values
  test_loss, test_acc = 0, 0

  # Loop through data loader data batches
  progress_bar = tqdm(
      enumerate(dataloader),
      desc=f"Testing Epoch {epoch}",
      total=len(dataloader),
      disable=disable_progress_bar
  )

  # Turn on inference context manager
  with torch.no_grad(): # no_grad() required for PyTorch 2.0, I found some errors with `torch.inference_mode()`, please let me know if this is not the case
      # Loop through DataLoader batches
      for batch, (X, y) in progress_bar:
          # Send data to target device
          X, y = X.to(device), y.to(device)

          # 1. Forward pass
          test_pred_logits = model(X)

          # 2. Calculate and accumulate loss
          loss = loss_fn(test_pred_logits, y)
          test_loss += loss.item()

          # Calculate and accumulate accuracy
          test_pred_labels = test_pred_logits.argmax(dim=1)
          test_acc += ((test_pred_labels == y).sum().item()/len(test_pred_labels))

          # Update progress bar
          progress_bar.set_postfix(
              {
                  "test_loss": test_loss / (batch + 1),
                  "test_acc": test_acc / (batch + 1),
              }
          )

  # Adjust metrics to get average loss and accuracy per batch
  test_loss = test_loss / len(dataloader)
  test_acc = test_acc / len(dataloader)
  return test_loss, test_acc

def train(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module,
          epochs: int,
          device: torch.device,
          disable_progress_bar: bool = False) -> Dict[str, List]:
  """Trains and tests a PyTorch model.

  Passes a target PyTorch models through train_step() and test_step()
  functions for a number of epochs, training and testing the model
  in the same epoch loop.

  Calculates, prints and stores evaluation metrics throughout.

  Args:
    model: A PyTorch model to be trained and tested.
    train_dataloader: A DataLoader instance for the model to be trained on.
    test_dataloader: A DataLoader instance for the model to be tested on.
    optimizer: A PyTorch optimizer to help minimize the loss function.
    loss_fn: A PyTorch loss function to calculate loss on both datasets.
    epochs: An integer indicating how many epochs to train for.
    device: A target device to compute on (e.g. "cuda" or "cpu").

  Returns:
    A dictionary of training and testing loss as well as training and
    testing accuracy metrics. Each metric has a value in a list for
    each epoch.
    In the form: {train_loss: [...],
                  train_acc: [...],
                  test_loss: [...],
                  test_acc: [...]}
    For example if training for epochs=2:
                 {train_loss: [2.0616, 1.0537],
                  train_acc: [0.3945, 0.3945],
                  test_loss: [1.2641, 1.5706],
                  test_acc: [0.3400, 0.2973]}
  """
  # Create empty results dictionary
  results = {"train_loss": [],
      "train_acc": [],
      "test_loss": [],
      "test_acc": [],
      "train_epoch_time": [],
      "test_epoch_time": []
  }

  # Loop through training and testing steps for a number of epochs
  for epoch in tqdm(range(epochs), disable=disable_progress_bar):

      # Perform training step and time it
      train_epoch_start_time = time.time()
      train_loss, train_acc = train_step(epoch=epoch,
                                        model=model,
                                        dataloader=train_dataloader,
                                        loss_fn=loss_fn,
                                        optimizer=optimizer,
                                        device=device,
                                        disable_progress_bar=disable_progress_bar)
      train_epoch_end_time = time.time()
      train_epoch_time = train_epoch_end_time - train_epoch_start_time

      # Perform testing step and time it
      test_epoch_start_time = time.time()
      test_loss, test_acc = test_step(epoch=epoch,
                                      model=model,
                                      dataloader=test_dataloader,
                                      loss_fn=loss_fn,
                                      device=device,
                                      disable_progress_bar=disable_progress_bar)
      test_epoch_end_time = time.time()
      test_epoch_time = test_epoch_end_time - test_epoch_start_time

      # Print out what's happening
      print(
          f"Epoch: {epoch+1} | "
          f"train_loss: {train_loss:.4f} | "
          f"train_acc: {train_acc:.4f} | "
          f"test_loss: {test_loss:.4f} | "
          f"test_acc: {test_acc:.4f} | "
          f"train_epoch_time: {train_epoch_time:.4f} | "
          f"test_epoch_time: {test_epoch_time:.4f}"
      )

      # Update results dictionary
      results["train_loss"].append(train_loss)
      results["train_acc"].append(train_acc)
      results["test_loss"].append(test_loss)
      results["test_acc"].append(test_acc)
      results["train_epoch_time"].append(train_epoch_time)
      results["test_epoch_time"].append(test_epoch_time)

  # Return the filled results at the end of the epochs
  return results

# %% [markdown]
# # Experiment num 1

# %%
NUM_EPOCHS = 5
LEARNING_RATE = 0.003

# %%
model, _ = create_model()
model.to(device)

loss_fn = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(),
                             lr=LEARNING_RATE)

# %%
single_run_no_compile_results = train(model=model,
                                      train_dataloader=train_dataloader,
                                      test_dataloader=test_dataloader,
                                      optimizer=optimizer,
                                      loss_fn=loss_fn,
                                      epochs=NUM_EPOCHS,
                                      device=device)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Training Epoch 0:   0%|          | 0/1563 [00:00<?, ?it/s]
# Testing Epoch 0:   0%|          | 0/313 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.1001 | train_acc: 0.6119 | test_loss: 0.7772 | test_acc: 0.7313 | train_epoch_time: 225.7806 | test_epoch_time: 19.0181
# Training Epoch 1:   0%|          | 0/1563 [00:00<?, ?it/s]
# Testing Epoch 1:   0%|          | 0/313 [00:00<?, ?it/s]
# Epoch: 2 | train_loss: 0.6542 | train_acc: 0.7739 | test_loss: 0.6555 | test_acc: 0.7730 | train_epoch_time: 230.1979 | test_epoch_time: 19.1683
# Training Epoch 2:   0%|          | 0/1563 [00:00<?, ?it/s]
# Testing Epoch 2:   0%|          | 0/313 [00:00<?, ?it/s]
# Epoch: 3 | train_loss: 0.4999 | train_acc: 0.8286 | test_loss: 0.5362 | test_acc: 0.8143 | train_epoch_time: 224.4776 | test_epoch_time: 18.6716
# Training Epoch 3:   0%|          | 0/1563 [00:00<?, ?it/s]
# Testing Epoch 3:   0%|          | 0/313 [00:00<?, ?it/s]
# Epoch: 4 | train_loss: 0.3957 | train_acc: 0.8636 | test_loss: 0.5222 | test_acc: 0.8274 | train_epoch_time: 224.6387 | test_epoch_time: 18.6380
# Training Epoch 4:   0%|          | 0/1563 [00:00<?, ?it/s]
# Testing Epoch 4:   0%|          | 0/313 [00:00<?, ?it/s]
# Epoch: 5 | train_loss: 0.3100 | train_acc: 0.8928 | test_loss: 0.4701 | test_acc: 0.8437 | train_epoch_time: 224.8045 | test_epoch_time: 18.8735

# %%
import torch._dynamo
torch._dynamo.config.suppress_errors = True
# Create model and transforms
model, transforms = create_model()
model.to(device)

# Create loss function and optimizer
loss_fn = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(),
                             lr=LEARNING_RATE)

# Compile the model and time how long it takes
compile_start_time = time.time()

### New in PyTorch 2.x ###
compiled_model = torch.compile(model)
##########################

compile_end_time = time.time()
compile_time = compile_end_time - compile_start_time
print(f"Time to compile: {compile_time} | Note: The first time you compile your model, the first few epochs will be slower than subsequent runs.")

# Train the compiled model
single_run_compile_results = train(model=compiled_model,
                                   train_dataloader=train_dataloader,
                                   test_dataloader=test_dataloader,
                                   loss_fn=loss_fn,
                                   optimizer=optimizer,
                                   epochs=NUM_EPOCHS,
                                   device=device)
# Out:
# Time to compile: 0.0007359981536865234 | Note: The first time you compile your model, the first few epochs will be slower than subsequent runs.
#   0%|          | 0/5 [00:00<?, ?it/s]
# Training Epoch 0:   0%|          | 0/1563 [00:00<?, ?it/s]
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING] WON'T CONVERT forward /usr/local/lib/python3.10/dist-packages/torchvision/models/resnet.py line 284
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING] due to:
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING] Traceback (most recent call last):
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 727, in _convert_frame
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     result = inner_convert(frame, cache_entry, hooks, frame_state)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 383, in _convert_frame_assert
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     compiled_product = _compile(
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 646, in _compile
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 244, in time_wrapper
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     r = func(*args, **kwargs)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 562, in compile_inner
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     out_code = transform_code_object(code, transform)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/bytecode_transformation.py", line 1033, in transform_code_object
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     transformations(instructions, code_options)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 151, in _fn
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     return fn(*args, **kwargs)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 527, in transform
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     tracer.run()
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 2128, in run
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     super().run()
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 818, in run
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     and self.step()
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 781, in step
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     getattr(self, inst.opname)(inst)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 2243, in RETURN_VALUE
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     self.output.compile_subgraph(
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 919, in compile_subgraph
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     return func(*args, **kwds)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1087, in compile_and_call_fx_graph
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     compiled_fn = self.call_user_compiler(gm)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 244, in time_wrapper
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     r = func(*args, **kwargs)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1159, in call_user_compiler
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1140, in call_user_compiler
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     compiled_fn = compiler_fn(gm, self.example_inputs())
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/repro/after_dynamo.py", line 117, in debug_wrapper
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     compiled_gm = compiler_fn(gm, example_inputs)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/__init__.py", line 1668, in __call__
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     return compile_fx(model_, inputs_, config_patches=self.config)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 1168, in compile_fx
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     return aot_autograd(
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/backends/common.py", line 55, in compiler_fn
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     cg = aot_module_simplified(gm, example_inputs, **kwargs)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/aot_autograd.py", line 887, in aot_module_simplified
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     compiled_fn = create_aot_dispatcher_function(
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 244, in time_wrapper
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     r = func(*args, **kwargs)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/aot_autograd.py", line 600, in create_aot_dispatcher_function
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     compiled_fn = compiler_fn(flat_fn, fake_flat_args, aot_config, fw_metadata=fw_metadata)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/_aot_autograd/runtime_wrappers.py", line 425, in aot_wrapper_dedupe
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     return compiler_fn(flat_fn, leaf_flat_args, aot_config, fw_metadata=fw_metadata)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/_aot_autograd/runtime_wrappers.py", line 630, in aot_wrapper_synthetic_base
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     return compiler_fn(flat_fn, flat_args, aot_config, fw_metadata=fw_metadata)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/_aot_autograd/jit_compile_runtime_wrappers.py", line 295, in aot_dispatch_autograd
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     compiled_fw_func = aot_config.fw_compiler(fw_module, adjusted_flat_args)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 244, in time_wrapper
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     r = func(*args, **kwargs)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 1100, in fw_compiler_base
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     return inner_compile(
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/repro/after_aot.py", line 83, in debug_wrapper
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/debug.py", line 305, in inner
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     return fn(*args, **kwargs)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     return func(*args, **kwds)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 320, in compile_fx_inner
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     compiled_graph = fx_codegen_and_compile(
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 550, in fx_codegen_and_compile
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     compiled_fn = graph.compile_to_fn()
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1116, in compile_to_fn
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     return self.compile_to_module().call
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 244, in time_wrapper
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     r = func(*args, **kwargs)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1070, in compile_to_module
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     mod = PyCodeCache.load_by_key_path(
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/codecache.py", line 1892, in load_by_key_path
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     exec(code, mod.__dict__, mod.__dict__)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/tmp/torchinductor_root/do/cdommljnpp2hjded2a6srfzf7uvrd3nfmn3xinkra63o6teg2eoh.py", line 28, in <module>
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     triton_poi_fused_0 = async_compile.triton('triton_', '''
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/codecache.py", line 2448, in triton
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     future = self.process_pool().submit(
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/lib/python3.10/concurrent/futures/process.py", line 720, in submit
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     raise BrokenProcessPool(self._broken)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING] BrokenProcessPool: A child process terminated abruptly, the process pool is not usable anymore
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING] Traceback (most recent call last):
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 727, in _convert_frame
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     result = inner_convert(frame, cache_entry, hooks, frame_state)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 383, in _convert_frame_assert
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     compiled_product = _compile(
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 646, in _compile
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 244, in time_wrapper
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     r = func(*args, **kwargs)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 562, in compile_inner
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     out_code = transform_code_object(code, transform)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/bytecode_transformation.py", line 1033, in transform_code_object
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     transformations(instructions, code_options)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 151, in _fn
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     return fn(*args, **kwargs)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 527, in transform
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     tracer.run()
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 2128, in run
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     super().run()
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 818, in run
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     and self.step()
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 781, in step
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     getattr(self, inst.opname)(inst)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 2243, in RETURN_VALUE
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     self.output.compile_subgraph(
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 919, in compile_subgraph
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     return func(*args, **kwds)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1087, in compile_and_call_fx_graph
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     compiled_fn = self.call_user_compiler(gm)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 244, in time_wrapper
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     r = func(*args, **kwargs)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1159, in call_user_compiler
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1140, in call_user_compiler
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     compiled_fn = compiler_fn(gm, self.example_inputs())
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/repro/after_dynamo.py", line 117, in debug_wrapper
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     compiled_gm = compiler_fn(gm, example_inputs)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/__init__.py", line 1668, in __call__
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     return compile_fx(model_, inputs_, config_patches=self.config)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 1168, in compile_fx
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     return aot_autograd(
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/backends/common.py", line 55, in compiler_fn
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     cg = aot_module_simplified(gm, example_inputs, **kwargs)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/aot_autograd.py", line 887, in aot_module_simplified
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     compiled_fn = create_aot_dispatcher_function(
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 244, in time_wrapper
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     r = func(*args, **kwargs)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/aot_autograd.py", line 600, in create_aot_dispatcher_function
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     compiled_fn = compiler_fn(flat_fn, fake_flat_args, aot_config, fw_metadata=fw_metadata)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/_aot_autograd/runtime_wrappers.py", line 425, in aot_wrapper_dedupe
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     return compiler_fn(flat_fn, leaf_flat_args, aot_config, fw_metadata=fw_metadata)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/_aot_autograd/runtime_wrappers.py", line 630, in aot_wrapper_synthetic_base
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     return compiler_fn(flat_fn, flat_args, aot_config, fw_metadata=fw_metadata)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/_aot_autograd/jit_compile_runtime_wrappers.py", line 295, in aot_dispatch_autograd
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     compiled_fw_func = aot_config.fw_compiler(fw_module, adjusted_flat_args)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 244, in time_wrapper
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     r = func(*args, **kwargs)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 1100, in fw_compiler_base
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     return inner_compile(
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/repro/after_aot.py", line 83, in debug_wrapper
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/debug.py", line 305, in inner
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     return fn(*args, **kwargs)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     return func(*args, **kwds)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 320, in compile_fx_inner
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     compiled_graph = fx_codegen_and_compile(
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 550, in fx_codegen_and_compile
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     compiled_fn = graph.compile_to_fn()
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1116, in compile_to_fn
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     return self.compile_to_module().call
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 244, in time_wrapper
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     r = func(*args, **kwargs)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1070, in compile_to_module
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     mod = PyCodeCache.load_by_key_path(
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/codecache.py", line 1892, in load_by_key_path
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     exec(code, mod.__dict__, mod.__dict__)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/tmp/torchinductor_root/do/cdommljnpp2hjded2a6srfzf7uvrd3nfmn3xinkra63o6teg2eoh.py", line 28, in <module>
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     triton_poi_fused_0 = async_compile.triton('triton_', '''
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/codecache.py", line 2448, in triton
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     future = self.process_pool().submit(
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]   File "/usr/lib/python3.10/concurrent/futures/process.py", line 720, in submit
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]     raise BrokenProcessPool(self._broken)
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING] BrokenProcessPool: A child process terminated abruptly, the process pool is not usable anymore
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# [2024-04-22 10:47:21,428] torch._dynamo.convert_frame: [WARNING]
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING] WON'T CONVERT _forward_impl /usr/local/lib/python3.10/dist-packages/torchvision/models/resnet.py line 266
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING] due to:
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING] Traceback (most recent call last):
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 727, in _convert_frame
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     result = inner_convert(frame, cache_entry, hooks, frame_state)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 383, in _convert_frame_assert
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     compiled_product = _compile(
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 646, in _compile
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 244, in time_wrapper
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     r = func(*args, **kwargs)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 562, in compile_inner
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     out_code = transform_code_object(code, transform)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/bytecode_transformation.py", line 1033, in transform_code_object
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     transformations(instructions, code_options)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 151, in _fn
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     return fn(*args, **kwargs)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 527, in transform
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     tracer.run()
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 2128, in run
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     super().run()
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 818, in run
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     and self.step()
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 781, in step
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     getattr(self, inst.opname)(inst)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 2243, in RETURN_VALUE
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     self.output.compile_subgraph(
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 919, in compile_subgraph
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     return func(*args, **kwds)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1087, in compile_and_call_fx_graph
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     compiled_fn = self.call_user_compiler(gm)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 244, in time_wrapper
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     r = func(*args, **kwargs)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1159, in call_user_compiler
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1140, in call_user_compiler
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     compiled_fn = compiler_fn(gm, self.example_inputs())
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/repro/after_dynamo.py", line 117, in debug_wrapper
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     compiled_gm = compiler_fn(gm, example_inputs)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/__init__.py", line 1668, in __call__
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     return compile_fx(model_, inputs_, config_patches=self.config)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 1168, in compile_fx
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     return aot_autograd(
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/backends/common.py", line 55, in compiler_fn
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     cg = aot_module_simplified(gm, example_inputs, **kwargs)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/aot_autograd.py", line 887, in aot_module_simplified
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     compiled_fn = create_aot_dispatcher_function(
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 244, in time_wrapper
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     r = func(*args, **kwargs)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/aot_autograd.py", line 600, in create_aot_dispatcher_function
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     compiled_fn = compiler_fn(flat_fn, fake_flat_args, aot_config, fw_metadata=fw_metadata)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/_aot_autograd/runtime_wrappers.py", line 425, in aot_wrapper_dedupe
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     return compiler_fn(flat_fn, leaf_flat_args, aot_config, fw_metadata=fw_metadata)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/_aot_autograd/runtime_wrappers.py", line 630, in aot_wrapper_synthetic_base
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     return compiler_fn(flat_fn, flat_args, aot_config, fw_metadata=fw_metadata)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/_aot_autograd/jit_compile_runtime_wrappers.py", line 295, in aot_dispatch_autograd
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     compiled_fw_func = aot_config.fw_compiler(fw_module, adjusted_flat_args)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 244, in time_wrapper
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     r = func(*args, **kwargs)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 1100, in fw_compiler_base
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     return inner_compile(
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/repro/after_aot.py", line 83, in debug_wrapper
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/debug.py", line 305, in inner
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     return fn(*args, **kwargs)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     return func(*args, **kwds)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 320, in compile_fx_inner
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     compiled_graph = fx_codegen_and_compile(
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 550, in fx_codegen_and_compile
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     compiled_fn = graph.compile_to_fn()
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1116, in compile_to_fn
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     return self.compile_to_module().call
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 244, in time_wrapper
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     r = func(*args, **kwargs)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1070, in compile_to_module
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     mod = PyCodeCache.load_by_key_path(
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/codecache.py", line 1892, in load_by_key_path
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     exec(code, mod.__dict__, mod.__dict__)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/tmp/torchinductor_root/do/cdommljnpp2hjded2a6srfzf7uvrd3nfmn3xinkra63o6teg2eoh.py", line 28, in <module>
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     triton_poi_fused_0 = async_compile.triton('triton_', '''
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/codecache.py", line 2448, in triton
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     future = self.process_pool().submit(
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/lib/python3.10/concurrent/futures/process.py", line 720, in submit
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     raise BrokenProcessPool(self._broken)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING] BrokenProcessPool: A child process terminated abruptly, the process pool is not usable anymore
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING] Traceback (most recent call last):
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 727, in _convert_frame
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     result = inner_convert(frame, cache_entry, hooks, frame_state)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 383, in _convert_frame_assert
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     compiled_product = _compile(
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 646, in _compile
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 244, in time_wrapper
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     r = func(*args, **kwargs)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 562, in compile_inner
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     out_code = transform_code_object(code, transform)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/bytecode_transformation.py", line 1033, in transform_code_object
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     transformations(instructions, code_options)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 151, in _fn
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     return fn(*args, **kwargs)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 527, in transform
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     tracer.run()
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 2128, in run
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     super().run()
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 818, in run
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     and self.step()
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 781, in step
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     getattr(self, inst.opname)(inst)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 2243, in RETURN_VALUE
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     self.output.compile_subgraph(
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 919, in compile_subgraph
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     return func(*args, **kwds)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1087, in compile_and_call_fx_graph
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     compiled_fn = self.call_user_compiler(gm)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 244, in time_wrapper
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     r = func(*args, **kwargs)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1159, in call_user_compiler
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1140, in call_user_compiler
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     compiled_fn = compiler_fn(gm, self.example_inputs())
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/repro/after_dynamo.py", line 117, in debug_wrapper
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     compiled_gm = compiler_fn(gm, example_inputs)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/__init__.py", line 1668, in __call__
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     return compile_fx(model_, inputs_, config_patches=self.config)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 1168, in compile_fx
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     return aot_autograd(
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/backends/common.py", line 55, in compiler_fn
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     cg = aot_module_simplified(gm, example_inputs, **kwargs)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/aot_autograd.py", line 887, in aot_module_simplified
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     compiled_fn = create_aot_dispatcher_function(
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 244, in time_wrapper
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     r = func(*args, **kwargs)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/aot_autograd.py", line 600, in create_aot_dispatcher_function
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     compiled_fn = compiler_fn(flat_fn, fake_flat_args, aot_config, fw_metadata=fw_metadata)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/_aot_autograd/runtime_wrappers.py", line 425, in aot_wrapper_dedupe
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     return compiler_fn(flat_fn, leaf_flat_args, aot_config, fw_metadata=fw_metadata)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/_aot_autograd/runtime_wrappers.py", line 630, in aot_wrapper_synthetic_base
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     return compiler_fn(flat_fn, flat_args, aot_config, fw_metadata=fw_metadata)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/_aot_autograd/jit_compile_runtime_wrappers.py", line 295, in aot_dispatch_autograd
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     compiled_fw_func = aot_config.fw_compiler(fw_module, adjusted_flat_args)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 244, in time_wrapper
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     r = func(*args, **kwargs)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 1100, in fw_compiler_base
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     return inner_compile(
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/repro/after_aot.py", line 83, in debug_wrapper
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/debug.py", line 305, in inner
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     return fn(*args, **kwargs)
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# [2024-04-22 10:47:47,060] torch._dynamo.convert_frame: [WARNING]     return func(*args, **kwds)
# ...
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     return func(*args, **kwds)
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 320, in compile_fx_inner
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     compiled_graph = fx_codegen_and_compile(
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 550, in fx_codegen_and_compile
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     compiled_fn = graph.compile_to_fn()
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1116, in compile_to_fn
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     return self.compile_to_module().call
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 244, in time_wrapper
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     r = func(*args, **kwargs)
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1070, in compile_to_module
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     mod = PyCodeCache.load_by_key_path(
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/codecache.py", line 1892, in load_by_key_path
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     exec(code, mod.__dict__, mod.__dict__)
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/tmp/torchinductor_root/pm/cpm667dmrn6bg5kbdmuwbgyl7g6rwrytymmzjwxt4uk76cexxgqv.py", line 28, in <module>
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     triton_poi_fused_0 = async_compile.triton('triton_', '''
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/codecache.py", line 2448, in triton
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     future = self.process_pool().submit(
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/lib/python3.10/concurrent/futures/process.py", line 720, in submit
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     raise BrokenProcessPool(self._broken)
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING] BrokenProcessPool: A child process terminated abruptly, the process pool is not usable anymore
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING] Traceback (most recent call last):
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 727, in _convert_frame
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     result = inner_convert(frame, cache_entry, hooks, frame_state)
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 383, in _convert_frame_assert
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     compiled_product = _compile(
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 646, in _compile
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 244, in time_wrapper
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     r = func(*args, **kwargs)
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 562, in compile_inner
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     out_code = transform_code_object(code, transform)
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/bytecode_transformation.py", line 1033, in transform_code_object
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     transformations(instructions, code_options)
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 151, in _fn
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     return fn(*args, **kwargs)
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 527, in transform
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     tracer.run()
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 2128, in run
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     super().run()
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 818, in run
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     and self.step()
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 781, in step
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     getattr(self, inst.opname)(inst)
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 2243, in RETURN_VALUE
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     self.output.compile_subgraph(
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 919, in compile_subgraph
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     return func(*args, **kwds)
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1087, in compile_and_call_fx_graph
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     compiled_fn = self.call_user_compiler(gm)
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 244, in time_wrapper
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     r = func(*args, **kwargs)
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1159, in call_user_compiler
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1140, in call_user_compiler
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     compiled_fn = compiler_fn(gm, self.example_inputs())
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/repro/after_dynamo.py", line 117, in debug_wrapper
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     compiled_gm = compiler_fn(gm, example_inputs)
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/__init__.py", line 1668, in __call__
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     return compile_fx(model_, inputs_, config_patches=self.config)
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 1168, in compile_fx
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     return aot_autograd(
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/backends/common.py", line 55, in compiler_fn
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     cg = aot_module_simplified(gm, example_inputs, **kwargs)
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/aot_autograd.py", line 887, in aot_module_simplified
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     compiled_fn = create_aot_dispatcher_function(
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 244, in time_wrapper
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     r = func(*args, **kwargs)
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/aot_autograd.py", line 600, in create_aot_dispatcher_function
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     compiled_fn = compiler_fn(flat_fn, fake_flat_args, aot_config, fw_metadata=fw_metadata)
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/_aot_autograd/runtime_wrappers.py", line 425, in aot_wrapper_dedupe
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     return compiler_fn(flat_fn, leaf_flat_args, aot_config, fw_metadata=fw_metadata)
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/_aot_autograd/runtime_wrappers.py", line 630, in aot_wrapper_synthetic_base
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     return compiler_fn(flat_fn, flat_args, aot_config, fw_metadata=fw_metadata)
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/_aot_autograd/jit_compile_runtime_wrappers.py", line 295, in aot_dispatch_autograd
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     compiled_fw_func = aot_config.fw_compiler(fw_module, adjusted_flat_args)
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 244, in time_wrapper
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     r = func(*args, **kwargs)
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 1100, in fw_compiler_base
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     return inner_compile(
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/repro/after_aot.py", line 83, in debug_wrapper
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/debug.py", line 305, in inner
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     return fn(*args, **kwargs)
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/lib/python3.10/contextlib.py", line 79, in inner
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     return func(*args, **kwds)
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 320, in compile_fx_inner
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     compiled_graph = fx_codegen_and_compile(
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 550, in fx_codegen_and_compile
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     compiled_fn = graph.compile_to_fn()
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1116, in compile_to_fn
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     return self.compile_to_module().call
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 244, in time_wrapper
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     r = func(*args, **kwargs)
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1070, in compile_to_module
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     mod = PyCodeCache.load_by_key_path(
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/codecache.py", line 1892, in load_by_key_path
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     exec(code, mod.__dict__, mod.__dict__)
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/tmp/torchinductor_root/pm/cpm667dmrn6bg5kbdmuwbgyl7g6rwrytymmzjwxt4uk76cexxgqv.py", line 28, in <module>
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     triton_poi_fused_0 = async_compile.triton('triton_', '''
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/codecache.py", line 2448, in triton
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     future = self.process_pool().submit(
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]   File "/usr/lib/python3.10/concurrent/futures/process.py", line 720, in submit
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]     raise BrokenProcessPool(self._broken)
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING] BrokenProcessPool: A child process terminated abruptly, the process pool is not usable anymore
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# [2024-04-22 10:47:48,837] torch._dynamo.convert_frame: [WARNING]
# Testing Epoch 0:   0%|          | 0/313 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.1255 | train_acc: 0.5986 | test_loss: 0.8011 | test_acc: 0.7231 | train_epoch_time: 281.8578 | test_epoch_time: 19.7228
# Training Epoch 1:   0%|          | 0/1563 [00:00<?, ?it/s]
