# %% [markdown]
# <a href="https://colab.research.google.com/github/hrnnikolov/ML_models/blob/main/SVR_models/SVR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# # Feature encoding

# %%
X = df.drop('total_bill', axis=1)
y = df['total_bill']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=33)

# %%
X_train
# Out:
#       tip     sex smoker   day    time  size
# 200  4.00    Male    Yes  Thur   Lunch     3
# 68   2.01    Male     No   Sat  Dinner     2
# 34   3.27    Male     No   Sat  Dinner     2
# 24   3.18    Male     No   Sat  Dinner     2
# 237  1.17    Male    Yes   Sat  Dinner     2
# ..    ...     ...    ...   ...     ...   ...
# 146  1.36  Female     No  Thur   Lunch     3
# 66   2.47  Female     No   Sat  Dinner     2
# 216  3.00    Male    Yes   Sat  Dinner     5
# 135  1.25  Female     No  Thur   Lunch     2
# 20   4.08    Male     No   Sat  Dinner     2
#
# [183 rows x 6 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le1 = LabelEncoder()
le2 = LabelEncoder()
le3 = LabelEncoder()

# %%
X_train['sex'] = le1.fit_transform(X_train['sex'])
X_train['smoker'] = le2.fit_transform(X_train['smoker'])
X_train['time'] = le3.fit_transform(X_train['time'])

# %%
X_train.head()
# Out:
#       tip  sex  smoker   day  time  size
# 200  4.00    1       1  Thur     1     3
# 68   2.01    1       0   Sat     0     2
# 34   3.27    1       0   Sat     0     2
# 24   3.18    1       0   Sat     0     2
# 237  1.17    1       1   Sat     0     2

# %%
X_train['sex'].value_counts()
# Out:
# sex
# 1    119
# 0     64
# Name: count, dtype: int64

# %%
X_test['sex'] = le1.transform(X_test['sex'])
X_test['smoker'] = le2.transform(X_test['smoker'])
X_test['time'] = le3.transform(X_test['time'])

# %%
X_test.head()
# Out:
#       tip  sex  smoker   day  time  size
# 203  2.50    0       1  Thur     1     2
# 70   1.97    1       0   Sat     0     2
# 95   4.73    1       1   Fri     0     4
# 120  2.31    1       0  Thur     1     2
# 103  3.48    0       1   Sat     0     2

# %% [markdown]
# # Onehot encoding

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('onehot', OneHotEncoder(drop='first'), [3])], remainder='passthrough')

# %%
import sys
import numpy
numpy.set_printoptions(threshold=sys.maxsize)
X_train = ct.fit_transform(X_train)

# %%
X_test = ct.transform(X_test)
X_test
# Out:
# array([[0.  , 0.  , 1.  , 2.5 , 0.  , 1.  , 1.  , 2.  ],
#        [1.  , 0.  , 0.  , 1.97, 1.  , 0.  , 0.  , 2.  ],
#        [0.  , 0.  , 0.  , 4.73, 1.  , 1.  , 0.  , 4.  ],
#        [0.  , 0.  , 1.  , 2.31, 1.  , 0.  , 1.  , 2.  ],
#        [1.  , 0.  , 0.  , 3.48, 0.  , 1.  , 0.  , 2.  ],
#        [0.  , 0.  , 0.  , 1.  , 0.  , 1.  , 0.  , 2.  ],
#        [0.  , 1.  , 0.  , 5.07, 1.  , 0.  , 0.  , 4.  ],
#        [1.  , 0.  , 0.  , 4.08, 0.  , 0.  , 0.  , 2.  ],
#        [0.  , 0.  , 1.  , 2.  , 1.  , 0.  , 1.  , 2.  ],
#        [0.  , 0.  , 1.  , 2.  , 0.  , 0.  , 1.  , 2.  ],
#        [0.  , 1.  , 0.  , 3.71, 1.  , 0.  , 0.  , 3.  ],
#        [1.  , 0.  , 0.  , 2.  , 1.  , 0.  , 0.  , 2.  ],
#        [1.  , 0.  , 0.  , 2.31, 1.  , 0.  , 0.  , 3.  ],
#        [0.  , 0.  , 0.  , 3.  , 0.  , 1.  , 0.  , 2.  ],
#        [0.  , 0.  , 1.  , 1.73, 1.  , 0.  , 1.  , 2.  ],
#        [0.  , 0.  , 1.  , 2.  , 1.  , 1.  , 1.  , 2.  ],
# ...

# %% [markdown]
# # SVR

# %%
from sklearn.svm import SVR
svr = SVR()
svr.fit(X_train, y_train)
# Out:
# SVR()

# %%
y_pred = svr.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_absolute_error
print(r2_score(y_test, y_pred))
print(mean_absolute_error(y_test, y_pred))
# Out:
# 0.5063510466739434
# 3.9065733335312602

# %% [markdown]
# # Hyperparameter Yuning using GrdiSearch CV

# %%
from sklearn.model_selection import GridSearchCV

param_grid = { 'C': [0.1, 1, 10, 100, 1000],
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf']}

# %%
grid = GridSearchCV(SVR(), param_grid, refit=True, verbose=3)

grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.027 total time=   0.0s
# [CV 2/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.051 total time=   0.0s
# [CV 3/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.109 total time=   0.0s
# [CV 4/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.036 total time=   0.0s
# [CV 5/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.089 total time=   0.0s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.116 total time=   0.0s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.018 total time=   0.0s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.020 total time=   0.0s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.064 total time=   0.0s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.000 total time=   0.0s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.025 total time=   0.0s
# ...

# %%
grid.best_params_
# Out:
# {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}

# %%
grid_predictions = grid.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_absolute_error
print(r2_score(y_test, grid_predictions))
print(mean_absolute_error(y_test, grid_predictions))
# Out:
# 0.5536857499705947
# 3.6957986301181665
