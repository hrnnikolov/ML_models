# %%
import pandas as pd

# %%
matches = pd.read_csv('matches.csv', index_col=0)

# %%
matches
# Out:
#           date   time            comp         round  day venue result   gf  \
# 1   2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2   2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3   2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4   2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6   2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..         ...    ...             ...           ...  ...   ...    ...  ...
# 38  2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39  2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40  2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41  2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42  2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#      ga        opponent  ...  match report  notes    sh   sot  dist   fk   pk  \
# 1   1.0       Tottenham  ...  Match Report    NaN  18.0   4.0  16.9  1.0  0.0
# 2   0.0    Norwich City  ...  Match Report    NaN  16.0   4.0  17.3  1.0  0.0
# 3   0.0         Arsenal  ...  Match Report    NaN  25.0  10.0  14.3  0.0  0.0
# 4   0.0  Leicester City  ...  Match Report    NaN  25.0   8.0  14.0  0.0  0.0
# 6   0.0     Southampton  ...  Match Report    NaN  16.0   1.0  15.7  1.0  0.0
# ..  ...             ...  ...           ...    ...   ...   ...   ...  ...  ...
# 38  4.0       Tottenham  ...  Match Report    NaN   8.0   1.0  17.4  0.0  0.0
# 39  2.0  Crystal Palace  ...  Match Report    NaN   7.0   0.0  11.4  1.0  0.0
# 40  0.0         Everton  ...  Match Report    NaN  10.0   3.0  17.0  0.0  0.0
# 41  1.0   Newcastle Utd  ...  Match Report    NaN  11.0   1.0  16.0  1.0  0.0
# 42  0.0         Burnley  ...  Match Report    NaN  12.0   3.0  17.0  0.0  0.0
#
#    pkatt  season              team
# 1    0.0    2022   Manchester City
# 2    0.0    2022   Manchester City
# 3    0.0    2022   Manchester City
# 4    0.0    2022   Manchester City
# 6    0.0    2022   Manchester City
# ..   ...     ...               ...
# 38   0.0    2021  Sheffield United
# 39   0.0    2021  Sheffield United
# 40   0.0    2021  Sheffield United
# 41   0.0    2021  Sheffield United
# 42   0.0    2021  Sheffield United
#
# [1389 rows x 27 columns]

# %%
matches['team'].value_counts()
# Out:
# Southampton                 72
# Brighton and Hove Albion    72
# Manchester United           72
# West Ham United             72
# Newcastle United            72
# Burnley                     71
# Leeds United                71
# Crystal Palace              71
# Manchester City             71
# Wolverhampton Wanderers     71
# Tottenham Hotspur           71
# Arsenal                     71
# Leicester City              70
# Chelsea                     70
# Aston Villa                 70
# Everton                     70
# Liverpool                   38
# Fulham                      38
# West Bromwich Albion        38
# Sheffield United            38
# Brentford                   34
# Watford                     33
# Norwich City                33
# Name: team, dtype: int64

# %%
matches['round'].value_counts()
# Out:
# Matchweek 1     39
# Matchweek 16    39
# Matchweek 34    39
# Matchweek 32    39
# Matchweek 31    39
# Matchweek 29    39
# Matchweek 28    39
# Matchweek 26    39
# Matchweek 25    39
# Matchweek 24    39
# Matchweek 23    39
# Matchweek 2     39
# Matchweek 19    39
# Matchweek 17    39
# Matchweek 20    39
# Matchweek 15    39
# Matchweek 5     39
# Matchweek 3     39
# Matchweek 13    39
# Matchweek 12    39
# Matchweek 4     39
# Matchweek 11    39
# Matchweek 10    39
# Matchweek 9     39
# Matchweek 8     39
# Matchweek 14    39
# Matchweek 7     39
# Matchweek 6     39
# Matchweek 30    37
# Matchweek 27    37
# Matchweek 22    37
# Matchweek 21    37
# Matchweek 18    37
# Matchweek 33    32
# Matchweek 35    20
# Matchweek 36    20
# Matchweek 37    20
# Matchweek 38    20
# Name: round, dtype: int64

# %%
matches['date'] = pd.to_datetime(matches['date'])

# %%
matches['venue_code'] = matches['venue'].astype('category').cat.codes

# %%
matches.head()
# Out:
#         date   time            comp        round  day venue result   gf   ga  \
# 1 2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L  0.0  1.0
# 2 2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W  5.0  0.0
# 3 2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W  5.0  0.0
# 4 2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W  1.0  0.0
# 6 2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...  notes    sh   sot  dist   fk   pk pkatt season  \
# 1       Tottenham  ...    NaN  18.0   4.0  16.9  1.0  0.0   0.0   2022
# 2    Norwich City  ...    NaN  16.0   4.0  17.3  1.0  0.0   0.0   2022
# 3         Arsenal  ...    NaN  25.0  10.0  14.3  0.0  0.0   0.0   2022
# 4  Leicester City  ...    NaN  25.0   8.0  14.0  0.0  0.0   0.0   2022
# 6     Southampton  ...    NaN  16.0   1.0  15.7  1.0  0.0   0.0   2022
#
#               team  venue_code
# 1  Manchester City           0
# 2  Manchester City           1
# 3  Manchester City           1
# 4  Manchester City           0
# 6  Manchester City           1
#
# [5 rows x 28 columns]

# %%
matches['opp_code'] = matches['opponent'].astype('category').cat.codes

# %%
matches['hour'] = matches['time'].str.replace(':.+', '', regex=True).astype('int')

# %%
matches['day_code'] = matches['date'].dt.dayofweek

# %%
matches['target'] = (matches['result'] == 'W').astype('int')

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches['date'] < '2022-01-01']
test = matches[matches['date'] > '2022-01-01']

# %%
matches.head()
# Out:
#         date   time            comp        round  day venue result   gf   ga  \
# 1 2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L  0.0  1.0
# 2 2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W  5.0  0.0
# 3 2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W  5.0  0.0
# 4 2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W  1.0  0.0
# 6 2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...   fk   pk  pkatt  season             team venue_code  \
# 1       Tottenham  ...  1.0  0.0    0.0    2022  Manchester City          0
# 2    Norwich City  ...  1.0  0.0    0.0    2022  Manchester City          1
# 3         Arsenal  ...  0.0  0.0    0.0    2022  Manchester City          1
# 4  Leicester City  ...  0.0  0.0    0.0    2022  Manchester City          0
# 6     Southampton  ...  1.0  0.0    0.0    2022  Manchester City          1
#
#   opp_code hour  day_code  target
# 1       18   16         6       0
# 2       15   15         5       1
# 3        0   12         5       1
# 4       10   15         5       1
# 6       17   15         5       0
#
# [5 rows x 32 columns]

# %%
predictors = ['venue_code', 'opp_code', 'hour', 'day_code']

# %%
rf.fit(train[predictors], train['target'])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
rf.score(test[predictors], test['target'])
# Out:
# 0.6123188405797102

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test['target'], preds)
acc
# Out:
# 0.6123188405797102

# %%
from sklearn.metrics import confusion_matrix

y_predicted = rf.predict(test[predictors])
cm = confusion_matrix(test['target'], y_predicted)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sn 
plt.figure(figsize=(7,5))
sn.heatmap(cm, annot= True)
plt.xlabel('Predict')
plt.ylabel('Truth')
# Out:
# Text(58.222222222222214, 0.5, 'Truth')

# %%
combined = pd.DataFrame(dict(actual=test['target'], prediction=preds))

# %%
pd.crosstab(index=combined['actual'], columns = combined['prediction'])
# Out:
# prediction    0   1
# actual
# 0           141  31
# 1            76  28

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test['target'], preds)
# Out:
# 0.4745762711864407

# %%
grouped_matches = matches.groupby('team')

# %%
group = grouped_matches.get_group('Manchester United')

# %%
group
# Out:
#          date   time            comp         round  day venue result   gf  \
# 0  2021-08-14  12:30  Premier League   Matchweek 1  Sat  Home      W  5.0
# 1  2021-08-22  14:00  Premier League   Matchweek 2  Sun  Away      D  1.0
# 2  2021-08-29  16:30  Premier League   Matchweek 3  Sun  Away      W  1.0
# 3  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Home      W  4.0
# 5  2021-09-19  14:00  Premier League   Matchweek 5  Sun  Away      W  2.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 55 2021-05-09  14:05  Premier League  Matchweek 35  Sun  Away      W  3.0
# 56 2021-05-11  18:00  Premier League  Matchweek 36  Tue  Home      L  1.0
# 57 2021-05-13  20:15  Premier League  Matchweek 34  Thu  Home      L  2.0
# 58 2021-05-18  18:00  Premier League  Matchweek 37  Tue  Home      D  1.0
# 59 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Away      W  2.0
#
#      ga        opponent  ...   fk   pk  pkatt  season               team  \
# 0   1.0    Leeds United  ...  0.0  0.0    0.0    2022  Manchester United
# 1   1.0     Southampton  ...  1.0  0.0    0.0    2022  Manchester United
# 2   0.0          Wolves  ...  1.0  0.0    0.0    2022  Manchester United
# 3   1.0   Newcastle Utd  ...  0.0  0.0    0.0    2022  Manchester United
# 5   1.0        West Ham  ...  0.0  0.0    0.0    2022  Manchester United
# ..  ...             ...  ...  ...  ...    ...     ...                ...
# 55  1.0     Aston Villa  ...  0.0  1.0    1.0    2021  Manchester United
# 56  2.0  Leicester City  ...  0.0  0.0    0.0    2021  Manchester United
# 57  4.0       Liverpool  ...  1.0  0.0    0.0    2021  Manchester United
# 58  1.0          Fulham  ...  2.0  0.0    0.0    2021  Manchester United
# 59  1.0          Wolves  ...  0.0  1.0    1.0    2021  Manchester United
#
#    venue_code opp_code hour  day_code  target
# 0           1        9   12         5       1
# 1           0       17   14         6       0
# 2           0       22   16         6       1
# 3           1       14   15         5       1
# 5           0       21   14         6       1
# ..        ...      ...  ...       ...     ...
# 55          0        1   14         6       1
# 56          1       10   18         1       0
# 57          1       11   20         3       0
# 58          1        8   18         1       0
# 59          0       22   16         6       1
#
# [72 rows x 32 columns]

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values('date')
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group= group.dropna(subset=new_cols)
    return group

# %%
cols = ['gf', 'ga', 'sh', 'sot', 'dist', 'fk', 'pk', 'pkatt']
new_cols = [f'{c}_roling' for c in cols]

# %%
matches_rolling = matches.groupby('team').apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 6  2020-10-04  14:00  Premier League   Matchweek 4
#                         7  2020-10-17  17:30  Premier League   Matchweek 5
#                         9  2020-10-25  19:15  Premier League   Matchweek 6
#                         11 2020-11-01  16:30  Premier League   Matchweek 7
#                         13 2020-11-08  19:15  Premier League   Matchweek 8
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 32 2022-03-13  14:00  Premier League  Matchweek 29
#                         33 2022-03-18  20:00  Premier League  Matchweek 30
#                         34 2022-04-02  15:00  Premier League  Matchweek 31
#                         35 2022-04-08  20:00  Premier League  Matchweek 32
#                         36 2022-04-24  14:00  Premier League  Matchweek 34
#
#                             day venue result   gf   ga         opponent  ...  \
# team                                                                     ...
# Arsenal                 6   Sun  Home      W  2.0  1.0    Sheffield Utd  ...
#                         7   Sat  Away      L  0.0  1.0  Manchester City  ...
#                         9   Sun  Home      L  0.0  1.0   Leicester City  ...
#                         11  Sun  Away      W  1.0  0.0   Manchester Utd  ...
#                         13  Sun  Home      L  0.0  3.0      Aston Villa  ...
# ...                         ...   ...    ...  ...  ...              ...  ...
# Wolverhampton Wanderers 32  Sun  Away      W  1.0  0.0          Everton  ...
#                         33  Fri  Home      L  2.0  3.0     Leeds United  ...
#                         34  Sat  Home      W  2.0  1.0      Aston Villa  ...
#                         35  Fri  Away      L  0.0  1.0    Newcastle Utd  ...
#                         36  Sun  Away      L  0.0  1.0          Burnley  ...
#
#                             day_code  target  gf_roling  ga_roling  sh_roling  \
# team
# Arsenal                 6          6       1   2.000000   1.333333   7.666667
#                         7          5       0   1.666667   1.666667   5.333333
#                         9          6       0   1.000000   1.666667   7.000000
#                         11         6       1   0.666667   1.000000   9.666667
#                         13         6       0   0.333333   0.666667   9.666667
# ...                              ...     ...        ...        ...        ...
# Wolverhampton Wanderers 32         6       1   1.333333   1.000000  12.333333
#                         33         4       0   1.666667   0.666667  12.333333
#                         34         5       1   2.333333   1.000000  13.000000
#                         35         4       0   1.666667   1.333333  13.000000
#                         36         6       0   1.333333   1.666667  10.000000
#
#                            sot_roling dist_roling fk_roling  pk_roling  \
# team
# Arsenal                 6    3.666667   14.733333  0.666667   0.000000
#                         7    3.666667   15.766667  0.000000   0.000000
#                         9    3.666667   16.733333  0.666667   0.000000
#                         11   4.000000   16.033333  1.000000   0.000000
#                         13   2.666667   18.033333  1.000000   0.333333
# ...                               ...         ...       ...        ...
# Wolverhampton Wanderers 32   3.666667   19.300000  0.000000   0.000000
#                         33   4.333333   19.600000  0.000000   0.000000
#                         34   5.333333   19.833333  0.000000   0.000000
#                         35   5.000000   18.533333  0.000000   0.000000
#                         36   4.666667   17.633333  0.000000   0.000000
#
#                             pkatt_roling
# team
# Arsenal                 6       0.000000
#                         7       0.000000
#                         9       0.000000
#                         11      0.000000
#                         13      0.333333
# ...                                  ...
# Wolverhampton Wanderers 32      0.000000
#                         33      0.000000
#                         34      0.000000
#                         35      0.000000
#                         36      0.000000
#
# [1317 rows x 40 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time            comp         round  day venue result   gf  \
# 6  2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W  2.0
# 7  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L  0.0
# 9  2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L  0.0
# 11 2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W  1.0
# 13 2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 32 2022-03-13  14:00  Premier League  Matchweek 29  Sun  Away      W  1.0
# 33 2022-03-18  20:00  Premier League  Matchweek 30  Fri  Home      L  2.0
# 34 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Home      W  2.0
# 35 2022-04-08  20:00  Premier League  Matchweek 32  Fri  Away      L  0.0
# 36 2022-04-24  14:00  Premier League  Matchweek 34  Sun  Away      L  0.0
#
#      ga         opponent  ...  day_code  target  gf_roling  ga_roling  \
# 6   1.0    Sheffield Utd  ...         6       1   2.000000   1.333333
# 7   1.0  Manchester City  ...         5       0   1.666667   1.666667
# 9   1.0   Leicester City  ...         6       0   1.000000   1.666667
# 11  0.0   Manchester Utd  ...         6       1   0.666667   1.000000
# 13  3.0      Aston Villa  ...         6       0   0.333333   0.666667
# ..  ...              ...  ...       ...     ...        ...        ...
# 32  0.0          Everton  ...         6       1   1.333333   1.000000
# 33  3.0     Leeds United  ...         4       0   1.666667   0.666667
# 34  1.0      Aston Villa  ...         5       1   2.333333   1.000000
# 35  1.0    Newcastle Utd  ...         4       0   1.666667   1.333333
# 36  1.0          Burnley  ...         6       0   1.333333   1.666667
#
#     sh_roling sot_roling dist_roling fk_roling  pk_roling  pkatt_roling
# 6    7.666667   3.666667   14.733333  0.666667   0.000000      0.000000
# 7    5.333333   3.666667   15.766667  0.000000   0.000000      0.000000
# 9    7.000000   3.666667   16.733333  0.666667   0.000000      0.000000
# 11   9.666667   4.000000   16.033333  1.000000   0.000000      0.000000
# 13   9.666667   2.666667   18.033333  1.000000   0.333333      0.333333
# ..        ...        ...         ...       ...        ...           ...
# 32  12.333333   3.666667   19.300000  0.000000   0.000000      0.000000
# 33  12.333333   4.333333   19.600000  0.000000   0.000000      0.000000
# 34  13.000000   5.333333   19.833333  0.000000   0.000000      0.000000
# 35  13.000000   5.000000   18.533333  0.000000   0.000000      0.000000
# 36  10.000000   4.666667   17.633333  0.000000   0.000000      0.000000
#
# [1317 rows x 40 columns]

# %%
matches_rolling = matches_rolling.reset_index()

# %%
matches_rolling
# Out:
#       index       date   time            comp         round  day venue result  \
# 0         6 2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W
# 1         7 2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L
# 2         9 2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L
# 3        11 2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W
# 4        13 2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L
# ...     ...        ...    ...             ...           ...  ...   ...    ...
# 1312     32 2022-03-13  14:00  Premier League  Matchweek 29  Sun  Away      W
# 1313     33 2022-03-18  20:00  Premier League  Matchweek 30  Fri  Home      L
# 1314     34 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Home      W
# 1315     35 2022-04-08  20:00  Premier League  Matchweek 32  Fri  Away      L
# 1316     36 2022-04-24  14:00  Premier League  Matchweek 34  Sun  Away      L
#
#        gf   ga  ... day_code  target  gf_roling  ga_roling  sh_roling  \
# 0     2.0  1.0  ...        6       1   2.000000   1.333333   7.666667
# 1     0.0  1.0  ...        5       0   1.666667   1.666667   5.333333
# 2     0.0  1.0  ...        6       0   1.000000   1.666667   7.000000
# 3     1.0  0.0  ...        6       1   0.666667   1.000000   9.666667
# 4     0.0  3.0  ...        6       0   0.333333   0.666667   9.666667
# ...   ...  ...  ...      ...     ...        ...        ...        ...
# 1312  1.0  0.0  ...        6       1   1.333333   1.000000  12.333333
# 1313  2.0  3.0  ...        4       0   1.666667   0.666667  12.333333
# 1314  2.0  1.0  ...        5       1   2.333333   1.000000  13.000000
# 1315  0.0  1.0  ...        4       0   1.666667   1.333333  13.000000
# 1316  0.0  1.0  ...        6       0   1.333333   1.666667  10.000000
#
#      sot_roling dist_roling fk_roling pk_roling  pkatt_roling
# 0      3.666667   14.733333  0.666667  0.000000      0.000000
# 1      3.666667   15.766667  0.000000  0.000000      0.000000
# 2      3.666667   16.733333  0.666667  0.000000      0.000000
# 3      4.000000   16.033333  1.000000  0.000000      0.000000
# 4      2.666667   18.033333  1.000000  0.333333      0.333333
# ...         ...         ...       ...       ...           ...
# 1312   3.666667   19.300000  0.000000  0.000000      0.000000
# 1313   4.333333   19.600000  0.000000  0.000000      0.000000
# 1314   5.333333   19.833333  0.000000  0.000000      0.000000
# 1315   5.000000   18.533333  0.000000  0.000000      0.000000
# 1316   4.666667   17.633333  0.000000  0.000000      0.000000
#
# [1317 rows x 41 columns]

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2022-01-01']
    test = data[data["date"] > '2022-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.625

# %%
combined = combined.merge(matches_rolling[['date', 'team', 'opponent', 'result']], left_index=True, right_index=True)

# %%
combined[combined['actual'] != combined['predicted']]
# Out:
#       actual  predicted       date                     team        opponent  \
# 56         1          0 2022-02-10                  Arsenal          Wolves
# 57         1          0 2022-02-19                  Arsenal       Brentford
# 61         0          1 2022-03-16                  Arsenal       Liverpool
# 62         1          0 2022-03-19                  Arsenal     Aston Villa
# 66         1          0 2022-04-20                  Arsenal         Chelsea
# ...      ...        ...        ...                      ...             ...
# 1304       1          0 2022-01-22  Wolverhampton Wanderers       Brentford
# 1307       1          0 2022-02-20  Wolverhampton Wanderers  Leicester City
# 1311       1          0 2022-03-10  Wolverhampton Wanderers         Watford
# 1312       1          0 2022-03-13  Wolverhampton Wanderers         Everton
# 1314       1          0 2022-04-02  Wolverhampton Wanderers     Aston Villa
#
#      result
# 56        W
# 57        W
# 61        L
# 62        W
# 66        W
# ...     ...
# 1304      W
# 1307      W
# 1311      W
# 1312      W
# 1314      W
#
# [92 rows x 6 columns]

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton", 
              "Manchester United": "Manchester Utd", 
              "Newcastle United": "Newcastle Utd", 
              "Tottenham Hotspur": "Tottenham", 
              "West Ham United": "West Ham", 
              "Wolverhampton Wanderers": "Wolves"} 
mapping = MissingDict(**map_values)

# %%
mapping['West Ham United']
# Out:
# 'West Ham'

# %%
combined['new_team'] = combined['team'].map(mapping)

# %%
combined
# Out:
#       actual  predicted       date                     team       opponent  \
# 55         0          0 2022-01-23                  Arsenal        Burnley
# 56         1          0 2022-02-10                  Arsenal         Wolves
# 57         1          0 2022-02-19                  Arsenal      Brentford
# 58         1          1 2022-02-24                  Arsenal         Wolves
# 59         1          1 2022-03-06                  Arsenal        Watford
# ...      ...        ...        ...                      ...            ...
# 1312       1          0 2022-03-13  Wolverhampton Wanderers        Everton
# 1313       0          0 2022-03-18  Wolverhampton Wanderers   Leeds United
# 1314       1          0 2022-04-02  Wolverhampton Wanderers    Aston Villa
# 1315       0          0 2022-04-08  Wolverhampton Wanderers  Newcastle Utd
# 1316       0          0 2022-04-24  Wolverhampton Wanderers        Burnley
#
#      result new_team
# 55        D  Arsenal
# 56        W  Arsenal
# 57        W  Arsenal
# 58        W  Arsenal
# 59        W  Arsenal
# ...     ...      ...
# 1312      W   Wolves
# 1313      L   Wolves
# 1314      W   Wolves
# 1315      L   Wolves
# 1316      L   Wolves
#
# [276 rows x 7 columns]

# %%
merged = combined.merge(combined, left_on=['date', 'new_team'], right_on=['date', 'opponent'])

# %%
merged
# Out:
#      actual_x  predicted_x       date                   team_x     opponent_x  \
# 0           0            0 2022-01-23                  Arsenal        Burnley
# 1           1            0 2022-02-10                  Arsenal         Wolves
# 2           1            0 2022-02-19                  Arsenal      Brentford
# 3           1            1 2022-02-24                  Arsenal         Wolves
# 4           1            1 2022-03-06                  Arsenal        Watford
# ..        ...          ...        ...                      ...            ...
# 257         1            0 2022-03-13  Wolverhampton Wanderers        Everton
# 258         0            0 2022-03-18  Wolverhampton Wanderers   Leeds United
# 259         1            0 2022-04-02  Wolverhampton Wanderers    Aston Villa
# 260         0            0 2022-04-08  Wolverhampton Wanderers  Newcastle Utd
# 261         0            0 2022-04-24  Wolverhampton Wanderers        Burnley
#
#     result_x new_team_x  actual_y  predicted_y                   team_y  \
# 0          D    Arsenal         0            0                  Burnley
# 1          W    Arsenal         0            0  Wolverhampton Wanderers
# 2          W    Arsenal         0            0                Brentford
# 3          W    Arsenal         0            0  Wolverhampton Wanderers
# 4          W    Arsenal         0            0                  Watford
# ..       ...        ...       ...          ...                      ...
# 257        W     Wolves         0            0                  Everton
# 258        L     Wolves         1            0             Leeds United
# 259        W     Wolves         0            0              Aston Villa
# 260        L     Wolves         1            0         Newcastle United
# 261        L     Wolves         1            0                  Burnley
#
#     opponent_y result_y     new_team_y
# 0      Arsenal        D        Burnley
# 1      Arsenal        L         Wolves
# 2      Arsenal        L      Brentford
# 3      Arsenal        L         Wolves
# 4      Arsenal        L        Watford
# ..         ...      ...            ...
# 257     Wolves        L        Everton
# 258     Wolves        W   Leeds United
# 259     Wolves        L    Aston Villa
# 260     Wolves        W  Newcastle Utd
# 261     Wolves        W        Burnley
#
# [262 rows x 13 columns]

# %%
merged[(merged['predicted_x'] == 1) & (merged['predicted_y'] == 0)]['actual_x'].value_counts()
# Out:
# 1    27
# 0    13
# Name: actual_x, dtype: int64
